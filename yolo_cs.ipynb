# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ln -s '/content/drive/My Drive/' /currdrive

# %%
import os
import cv2
import matplotlib.pyplot as plt

# %%
path = '/currdrive/yolo/darknet'
os.chdir(path)
# !make
# Out:
# chmod +x *.sh

# %%
# !sudo chmod +x darknet

# %%
# !wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.weights
# Out:
# usage: ./darknet <function>

# %% [markdown]
# ### Utilizando Yolo treinado com o coco dataset

# %%
# !./darknet detector test cfg/coco.data cfg/yolov4.cfg yolov4.weights data/img_147.jpeg

# %%
# %matplotlib inline
image = cv2.imread('predictions.jpg')
image = image[:,:, ::-1]
fig = plt.gcf()
fig.set_size_inches(12,14)
plt.imshow(image)

# %% [markdown]
# ### Utilizando Yolo treinado para identificar terrorista e ct

# %%
#!./darknet detector test data/dataset/image_data.data cfg/yolov4_test.cfg /currdrive/yolo/darknet/backup/yolov4_train_2000.weights /currdrive/yolo/darknet/data/img_147.jpeg# -thresh 0.8
# !./darknet detector test data/dataset/image_data.data cfg/yolov4_test.cfg backup/yolov4_train_2000.weights data/img_147.jpeg

# %%
# %matplotlib inline
image = cv2.imread('predictions.jpg')
image = image[:,:, ::-1]
fig = plt.gcf()
fig.set_size_inches(12,14)
plt.imshow(image)

# %%
# !./darknet detector demo data/dataset/image_data.data cfg/yolov4_test.cfg backup/yolov4_train_2000.weights -dont_show data/counter_strike.mp4 -out_filename counter_strike_with_label.mp4

# %%
from google.colab import files
files.download('counter_strike_with_label.mp4')
